# %%
import numpy as np
import pandas as pd
df = pd.read_csv('spam.csv')
df.sample(5)
# Out:
#                                                   Type Unnamed: 1 Unnamed: 2  \
# 333  ham\t"Aww you must be nearly dead!Well Jez isC...        NaN        NaN
# 262  ham\tI cant pick the phone right now. Pls send...        NaN        NaN
# 189  ham\tCongrats ! Treat pending.i am not on mail...        NaN        NaN
# 405  ham\tI emailed yifeng my part oredi.. Can ü ge...        NaN        NaN
# 110  ham\tSorry i now then c ur msg... Yar lor so p...        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 333        NaN        NaN        NaN        NaN
# 262        NaN        NaN        NaN        NaN
# 189        NaN        NaN        NaN        NaN
# 405        NaN        NaN        NaN        NaN
# 110        NaN        NaN        NaN        NaN

# %%
df.shape
# Out:
# (656, 7)

# %%
df.sample(5)df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)
# Out:
#                                                   Type  \
# 66                        ham\tI am sorry it hurt you.
# 78   ham\tShe went to attend another two rounds tod...
# 99   ham\tI sent my scores to sophas and i had to d...
# 213  ham\tOK i'm waliking ard now... Do u wan me 2 ...
# 118  ham\tYo chad which gymnastics class do you wan...
#
#                                             Unnamed: 1 Unnamed: 5 Unnamed: 6
# 66                                                 NaN        NaN        NaN
# 78                                                 NaN        NaN        NaN
# 99    do a research on cost also. Contact joke ogun...        NaN        NaN
# 213                                                NaN        NaN        NaN
# 118                                                NaN        NaN        NaN

# %%
df.rename(columns={'Type':'target'},inplace=True)
df.sample(5)
# Out:
#                                                 target  \
# 580   ham\tOh thanks a lot..i already bought 2 eggs ..
# 113  ham\tMy sort code is  and acc no is . The bank...
# 424  ham\tNeither [in sterm voice] - i'm studying. ...
# 520                                       ham\tEr yeah
# 596  ham\tWhat i told before i tell. Stupid hear af...
#
#                         Unnamed: 1 Unnamed: 5 Unnamed: 6
# 580                            NaN        NaN        NaN
# 113                            NaN        NaN        NaN
# 424   tho. Anyway. Have a fab hols        NaN        NaN
# 520        i will b there at 15:26        NaN        NaN
# 596                            NaN        NaN        NaN

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])
df.head()
# Out:
#    target                                         Unnamed: 1 Unnamed: 5  \
# 0     111   crazy.. Available only in bugis n great world...        NaN
# 1     352                                                NaN        NaN
# 2     582                                                NaN        NaN
# 3     461                                                NaN        NaN
# 4     301                        he lives around here though        NaN
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.isnull().sum()
# Out:
# target          0
# Unnamed: 1    510
# Unnamed: 5    651
# Unnamed: 6    652
# dtype: int64

# %%
df.drop(columns=['Unnamed: 1','Unnamed: 5','Unnamed: 6'],inplace=True)
df.sample(5)
# Out:
#      target
# 28      107
# 280     207
# 635     236
# 418     511
# 232       4

# %%
df.isnull().sum()
# Out:
# target    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df = df.drop_duplicates(keep='first')

# %%
df.sample(5)
# Out:
#      target
# 448     346
# 583     594
# 0       111
# 251     362
# 18      357

# %%
df.shape
# Out:
# (638, 1)

# %%
df.head()
# Out:
#    target
# 0     111
# 1     352
# 2     582
# 3     461
# 4     301

# %%
df['target'].value_counts()
# Out:
# 111    1
# 478    1
# 414    1
# 541    1
# 36     1
#       ..
# 332    1
# 8      1
# 304    1
# 628    1
# 508    1
# Name: target, Length: 638, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['target'].value_counts(),autopct="%0.2f")
plt.show()
